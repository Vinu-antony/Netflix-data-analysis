# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("netflix_titles.csv")
df.head(10)
df.info()
df.describe()
df.isnull().sum()
# Drop rows with missing values
df.dropna(subset=['director','cast'],inplace=True)
df.fillna({'rating':'Not rated'},inplace=True)
df = df.dropna(subset=['date_added'])
invalid_dates = df[~df['date_added'].str.match(r'\w+ \d{1,2}, \d{4}', na=False)]
print(invalid_dates)
sns.countplot(x=df['type'], palette='coolwarm')
plt.title('Distribution of Movies and TV Shows on Netflix')
plt.show()
top_countries = df['country'].value_counts().head(10)
top_countries.plot(kind='bar', color='teal')
plt.title('Top 10 Countries with Most Netflix Titles')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
from collections import Counter

genres = ','.join(df['listed_in'].dropna()).split(', ')
genre_counts = Counter(genres)
top_genres = genre_counts.most_common(10)

# Convert to DataFrame for visualization
genre_df = pd.DataFrame(top_genres, columns=['Genre', 'Count'])
sns.barplot(x='Count', y='Genre', data=genre_df, palette='magma')
plt.title('Top 10 Most Popular Genres on Netflix')
plt.show()

df['release_year'].value_counts().sort_index().plot(kind='line', marker='o', color='green')
plt.title('Number of Releases Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

from wordcloud import WordCloud

text = ' '.join(df['title'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='black').generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
#      show_id     type            title                 director  \
# 6079   s6080  TV Show  Abnormal Summit  Jung-ah Im, Seung-uk Jo
# 6742   s6743  TV Show     Father Brown               Ian Barber
# 7409   s7410  TV Show             Mars            Everardo Gout
# 7896   s7897  TV Show      Royal Pains        Jay Chandrasekhar
#
#                                                    cast         country  \
# 6079           Hyun-moo Jun, Si-kyung Sung, Se-yoon Yoo     South Korea
# 6742  Mark Williams, Sorcha Cusack, Nancy Carroll, A...  United Kingdom
# 7409  Jihae, Alberto Ammann, Clémentine Poidatz, Ana...   United States
# 7896  Mark Feuerstein, Paulo Costanzo, Reshma Shetty...   United States
#
#              date_added  release_year rating   duration  \
# 6079     August 4, 2017          2017  TV-PG  2 Seasons
# 6742     March 31, 2018          2017  TV-14  6 Seasons
# 7409   November 1, 2019          2018  TV-PG  2 Seasons
# 7896       May 18, 2017          2016  TV-PG  8 Seasons
#
#                                               listed_in  \
# 6079  International TV Shows, Korean TV Shows, Stand...
# 6742        British TV Shows, Crime TV Shows, TV Dramas
# 7409         Docuseries, Science & Nature TV, TV Dramas
# 7896                             TV Comedies, TV Dramas
#
#                                             description
# 6079  Led by a trio of Korean celebs, a multinationa...
# 6742  A modest, compassionate priest doubles as an e...
# 7409  Fact meets fiction in this docudrama chronicli...
# 7896  Dr. Hank Lawson unexpectedly gets a career upg...
# C:\Users\Vinusha\AppData\Local\Temp\ipykernel_14748\3575844175.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['type'], palette='coolwarm')
# C:\Users\Vinusha\AppData\Local\Temp\ipykernel_14748\3575844175.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='Genre', data=genre_df, palette='magma')
# 2025-02-16 16:31:30.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-16 16:31:30.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-16 16:31:30.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-16 16:31:30.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-16 16:31:30.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-16 16:31:30.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-16 16:31:30.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-16 16:31:30.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
